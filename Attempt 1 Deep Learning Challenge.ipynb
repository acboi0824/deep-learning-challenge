# %% [markdown]
# ## Preprocessing

# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf

# %%
#  Import and read the charity_data.csv.
application_df = pd.read_csv("Resources/charity_data.csv")
application_df.head()
# Out:
#         EIN                                      NAME APPLICATION_TYPE  \
# 0  10520599              BLUE KNIGHTS MOTORCYCLE CLUB              T10
# 1  10531628    AMERICAN CHESAPEAKE CLUB CHARITABLE TR               T3
# 2  10547893        ST CLOUD PROFESSIONAL FIREFIGHTERS               T5
# 3  10553066            SOUTHSIDE ATHLETIC ASSOCIATION               T3
# 4  10556103  GENETIC RESEARCH INSTITUTE OF THE DESERT               T3
#
#         AFFILIATION CLASSIFICATION      USE_CASE  ORGANIZATION  STATUS  \
# 0       Independent          C1000    ProductDev   Association       1
# 1       Independent          C2000  Preservation  Co-operative       1
# 2  CompanySponsored          C3000    ProductDev   Association       1
# 3  CompanySponsored          C2000  Preservation         Trust       1
# 4       Independent          C1000     Heathcare         Trust       1
#
#       INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  IS_SUCCESSFUL
# 0              0                      N     5000              1
# 1         1-9999                      N   108590              1
# 2              0                      N     5000              0
# 3    10000-24999                      N     6692              1
# 4  100000-499999                      N   142590              1

# %%
# checking for null values
print(application_df.isnull().sum())
print(application_df.duplicated().sum())
# Out:
# EIN                       0
# NAME                      0
# APPLICATION_TYPE          0
# AFFILIATION               0
# CLASSIFICATION            0
# USE_CASE                  0
# ORGANIZATION              0
# STATUS                    0
# INCOME_AMT                0
# SPECIAL_CONSIDERATIONS    0
# ASK_AMT                   0
# IS_SUCCESSFUL             0
# dtype: int64
# 0

# %%
# Drop the non-beneficial ID columns, 'EIN' and 'NAME'.
application_df.drop(columns=["EIN","NAME"],inplace=True)
application_df
# Out:
#       APPLICATION_TYPE       AFFILIATION CLASSIFICATION      USE_CASE  \
# 0                  T10       Independent          C1000    ProductDev
# 1                   T3       Independent          C2000  Preservation
# 2                   T5  CompanySponsored          C3000    ProductDev
# 3                   T3  CompanySponsored          C2000  Preservation
# 4                   T3       Independent          C1000     Heathcare
# ...                ...               ...            ...           ...
# 34294               T4       Independent          C1000    ProductDev
# 34295               T4  CompanySponsored          C3000    ProductDev
# 34296               T3  CompanySponsored          C2000  Preservation
# 34297               T5       Independent          C3000    ProductDev
# 34298               T3       Independent          C1000  Preservation
#
#        ORGANIZATION  STATUS     INCOME_AMT SPECIAL_CONSIDERATIONS   ASK_AMT  \
# 0       Association       1              0                      N      5000
# 1      Co-operative       1         1-9999                      N    108590
# 2       Association       1              0                      N      5000
# 3             Trust       1    10000-24999                      N      6692
# 4             Trust       1  100000-499999                      N    142590
# ...             ...     ...            ...                    ...       ...
# 34294   Association       1              0                      N      5000
# 34295   Association       1              0                      N      5000
# 34296   Association       1              0                      N      5000
# 34297   Association       1              0                      N      5000
# 34298  Co-operative       1          1M-5M                      N  36500179
#
#        IS_SUCCESSFUL
# 0                  1
# 1                  1
# 2                  0
# 3                  1
# 4                  1
# ...              ...
# 34294              0
# 34295              0
# 34296              0
# 34297              1
# 34298              0
#
# [34299 rows x 10 columns]

# %%
# Determine the number of unique values in each column.
for i in application_df.columns:
    print(i,len(application_df[i].unique()))
# Out:
# APPLICATION_TYPE 17
# AFFILIATION 6
# CLASSIFICATION 71
# USE_CASE 5
# ORGANIZATION 4
# STATUS 2
# INCOME_AMT 9
# SPECIAL_CONSIDERATIONS 2
# ASK_AMT 8747
# IS_SUCCESSFUL 2

# %%
# Look at APPLICATION_TYPE value counts for binning
app_count = application_df['APPLICATION_TYPE'].value_counts()
app_count
# Out:
# T3     27037
# T4      1542
# T6      1216
# T5      1173
# T19     1065
# T8       737
# T7       725
# T10      528
# T9       156
# T13       66
# T12       27
# T2        16
# T14        3
# T25        3
# T29        2
# T15        2
# T17        1
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Choose a cutoff value and create a list of application types to be replaced
# use the variable name `application_types_to_replace`
application_types_to_replace = list(app_count[app_count<200].index)

# Replace in dataframe
for app in application_types_to_replace:
    application_df['APPLICATION_TYPE'] = application_df['APPLICATION_TYPE'].replace(app,"Other")

# Check to make sure binning was successful
application_df['APPLICATION_TYPE'].value_counts()
# Out:
# T3       27037
# T4        1542
# T6        1216
# T5        1173
# T19       1065
# T8         737
# T7         725
# T10        528
# Other      276
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Look at CLASSIFICATION value counts for binning
class_count = application_df["CLASSIFICATION"].value_counts()
class_count.head(30)
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
# C7000      777
# C1700      287
# C4000      194
# C5000      116
# C1270      114
# C2700      104
# C2800       95
# C7100       75
# C1300       58
# C1280       50
# C1230       36
# C1400       34
# C7200       32
# C2300       32
# C1240       30
# C8000       20
# C7120       18
# C1500       16
# C6000       15
# C1800       15
# C1250       14
# C8200       11
# C1278       10
# C1238       10
# C1237        9
# Name: CLASSIFICATION, dtype: int64

# %%
# Choose a cutoff value and create a list of classifications to be replaced
# use the variable name `classifications_to_replace`
classifications_to_replace = list(class_count[class_count<100].index)
# Replace in dataframe
for cls in classifications_to_replace:
    application_df['CLASSIFICATION'] = application_df['CLASSIFICATION'].replace(cls,"Other")
    
# Check to make sure binning was successful
application_df['CLASSIFICATION'].value_counts()
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
# C7000      777
# Other      669
# C1700      287
# C4000      194
# C5000      116
# C1270      114
# C2700      104
# Name: CLASSIFICATION, dtype: int64

# %%
# Convert categorical data to numeric with `pd.get_dummies`
dummy_df = pd.get_dummies(application_df)
dummy_df
# Out:
#        STATUS   ASK_AMT  IS_SUCCESSFUL  APPLICATION_TYPE_Other  \
# 0           1      5000              1                       0
# 1           1    108590              1                       0
# 2           1      5000              0                       0
# 3           1      6692              1                       0
# 4           1    142590              1                       0
# ...       ...       ...            ...                     ...
# 34294       1      5000              0                       0
# 34295       1      5000              0                       0
# 34296       1      5000              0                       0
# 34297       1      5000              1                       0
# 34298       1  36500179              0                       0
#
#        APPLICATION_TYPE_T10  APPLICATION_TYPE_T19  APPLICATION_TYPE_T3  \
# 0                         1                     0                    0
# 1                         0                     0                    1
# 2                         0                     0                    0
# 3                         0                     0                    1
# 4                         0                     0                    1
# ...                     ...                   ...                  ...
# 34294                     0                     0                    0
# 34295                     0                     0                    0
# 34296                     0                     0                    1
# 34297                     0                     0                    0
# 34298                     0                     0                    1
#
#        APPLICATION_TYPE_T4  APPLICATION_TYPE_T5  APPLICATION_TYPE_T6  ...  \
# 0                        0                    0                    0  ...
# 1                        0                    0                    0  ...
# 2                        0                    1                    0  ...
# 3                        0                    0                    0  ...
# 4                        0                    0                    0  ...
# ...                    ...                  ...                  ...  ...
# 34294                    1                    0                    0  ...
# 34295                    1                    0                    0  ...
# 34296                    0                    0                    0  ...
# 34297                    0                    1                    0  ...
# 34298                    0                    0                    0  ...
#
#        INCOME_AMT_1-9999  INCOME_AMT_10000-24999  INCOME_AMT_100000-499999  \
# 0                      0                       0                         0
# 1                      1                       0                         0
# 2                      0                       0                         0
# 3                      0                       1                         0
# 4                      0                       0                         1
# ...                  ...                     ...                       ...
# 34294                  0                       0                         0
# 34295                  0                       0                         0
# 34296                  0                       0                         0
# 34297                  0                       0                         0
# 34298                  0                       0                         0
#
#        INCOME_AMT_10M-50M  INCOME_AMT_1M-5M  INCOME_AMT_25000-99999  \
# 0                       0                 0                       0
# 1                       0                 0                       0
# 2                       0                 0                       0
# 3                       0                 0                       0
# 4                       0                 0                       0
# ...                   ...               ...                     ...
# 34294                   0                 0                       0
# 34295                   0                 0                       0
# 34296                   0                 0                       0
# 34297                   0                 0                       0
# 34298                   0                 1                       0
#
#        INCOME_AMT_50M+  INCOME_AMT_5M-10M  SPECIAL_CONSIDERATIONS_N  \
# 0                    0                  0                         1
# 1                    0                  0                         1
# 2                    0                  0                         1
# 3                    0                  0                         1
# 4                    0                  0                         1
# ...                ...                ...                       ...
# 34294                0                  0                         1
# 34295                0                  0                         1
# 34296                0                  0                         1
# 34297                0                  0                         1
# 34298                0                  0                         1
#
#        SPECIAL_CONSIDERATIONS_Y
# 0                             0
# 1                             0
# 2                             0
# 3                             0
# 4                             0
# ...                         ...
# 34294                         0
# 34295                         0
# 34296                         0
# 34297                         0
# 34298                         0
#
# [34299 rows x 50 columns]

# %%
# Split our preprocessed data into our features and target arrays
y = dummy_df["IS_SUCCESSFUL"]
X = dummy_df.drop(["IS_SUCCESSFUL"],axis=1)

# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# ## Compile, Train and Evaluate the Model

# %% [markdown]
# Attempt 1 Info and Results:
# APPLICATION_TYPE cutoff = 200
# CLASSIFICATION cutoff = 100
# layer1 = 5 : activation function = relu
# layer2 = 10 : activation function = relu
#
# Loss: 0.557812534073699, Accuracy: 0.7262973785400391
# Loss value of 55 indicates that the model can be better optimized.
# The accuracy percent shows that 72% of the model's predicted values align with the true values in the original dataset.

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
number_input_features = len(X_train_scaled[0])
hidden_nodes_layer1 = 5
hidden_nodes_layer2 = 10

nn = tf.keras.models.Sequential()

# First hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer1, input_dim=number_input_features, activation="relu"))

# Second hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer2, activation="relu"))

# Output layer
nn.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_3 (Dense)             (None, 5)                 250
#
#  dense_4 (Dense)             (None, 10)                60
#
#  dense_5 (Dense)             (None, 1)                 11
#
# =================================================================
# Total params: 321
# Trainable params: 321
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
nn.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# Train the model
fit_model = nn.fit(X_train_scaled,y_train,epochs=100)
# Out:
# Epoch 1/100
# 804/804 [==============================] - 5s 3ms/step - loss: 0.6266 - accuracy: 0.6691
# Epoch 2/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5697 - accuracy: 0.7228
# Epoch 3/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5609 - accuracy: 0.7279
# Epoch 4/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5577 - accuracy: 0.7280
# Epoch 5/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5562 - accuracy: 0.7278
# Epoch 6/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5543 - accuracy: 0.7284
# Epoch 7/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5531 - accuracy: 0.7279
# Epoch 8/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5514 - accuracy: 0.7280
# Epoch 9/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5506 - accuracy: 0.7291
# Epoch 10/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5499 - accuracy: 0.7282
# Epoch 11/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5495 - accuracy: 0.7299
# Epoch 12/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5490 - accuracy: 0.7308
# Epoch 13/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5488 - accuracy: 0.7305
# Epoch 14/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5485 - accuracy: 0.7324
# Epoch 15/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5483 - accuracy: 0.7310
# Epoch 16/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5481 - accuracy: 0.7315
# Epoch 17/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5475 - accuracy: 0.7310
# Epoch 18/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5477 - accuracy: 0.7316
# Epoch 19/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5476 - accuracy: 0.7313
# Epoch 20/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5475 - accuracy: 0.7328
# Epoch 21/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5470 - accuracy: 0.7321
# Epoch 22/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5471 - accuracy: 0.7324
# Epoch 23/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5469 - accuracy: 0.7320
# Epoch 24/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5470 - accuracy: 0.7320
# Epoch 25/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5465 - accuracy: 0.7315
# Epoch 26/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5469 - accuracy: 0.7324
# Epoch 27/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5465 - accuracy: 0.7328
# Epoch 28/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5466 - accuracy: 0.7326
# Epoch 29/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5465 - accuracy: 0.7321
# Epoch 30/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5464 - accuracy: 0.7326
# Epoch 31/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5464 - accuracy: 0.7319
# Epoch 32/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5463 - accuracy: 0.7319
# Epoch 33/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5461 - accuracy: 0.7318
# Epoch 34/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5459 - accuracy: 0.7327
# Epoch 35/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5460 - accuracy: 0.7322
# Epoch 36/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5459 - accuracy: 0.7324
# Epoch 37/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5458 - accuracy: 0.7324
# Epoch 38/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5459 - accuracy: 0.7325
# Epoch 39/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5459 - accuracy: 0.7324
# Epoch 40/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5454 - accuracy: 0.7329
# Epoch 41/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5455 - accuracy: 0.7326
# Epoch 42/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5456 - accuracy: 0.7324
# Epoch 43/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5453 - accuracy: 0.7320
# Epoch 44/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5453 - accuracy: 0.7334
# Epoch 45/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5450 - accuracy: 0.7332
# Epoch 46/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5451 - accuracy: 0.7320
# Epoch 47/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5452 - accuracy: 0.7329
# Epoch 48/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5454 - accuracy: 0.7327
# Epoch 49/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5451 - accuracy: 0.7332
# Epoch 50/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5451 - accuracy: 0.7327
# Epoch 51/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5450 - accuracy: 0.7323
# Epoch 52/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5449 - accuracy: 0.7333
# Epoch 53/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5449 - accuracy: 0.7325
# Epoch 54/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5451 - accuracy: 0.7318
# Epoch 55/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5447 - accuracy: 0.7331
# Epoch 56/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5448 - accuracy: 0.7336
# Epoch 57/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5448 - accuracy: 0.7332
# Epoch 58/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5447 - accuracy: 0.7329
# Epoch 59/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5445 - accuracy: 0.7329
# Epoch 60/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5448 - accuracy: 0.7332
# Epoch 61/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5445 - accuracy: 0.7324
# Epoch 62/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5447 - accuracy: 0.7332
# Epoch 63/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5443 - accuracy: 0.7326
# Epoch 64/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5446 - accuracy: 0.7328
# Epoch 65/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5445 - accuracy: 0.7327
# Epoch 66/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5446 - accuracy: 0.7313
# Epoch 67/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5447 - accuracy: 0.7331
# Epoch 68/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5446 - accuracy: 0.7324
# Epoch 69/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5445 - accuracy: 0.7321
# Epoch 70/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5446 - accuracy: 0.7321
# Epoch 71/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5445 - accuracy: 0.7332
# Epoch 72/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5444 - accuracy: 0.7332
# Epoch 73/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5445 - accuracy: 0.7334
# Epoch 74/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5444 - accuracy: 0.7325
# Epoch 75/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5443 - accuracy: 0.7325
# Epoch 76/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5442 - accuracy: 0.7331
# Epoch 77/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5443 - accuracy: 0.7329
# Epoch 78/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5439 - accuracy: 0.7341
# Epoch 79/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5442 - accuracy: 0.7335
# Epoch 80/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5440 - accuracy: 0.7333
# Epoch 81/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5443 - accuracy: 0.7333
# Epoch 82/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5443 - accuracy: 0.7327
# Epoch 83/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5441 - accuracy: 0.7344
# Epoch 84/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5440 - accuracy: 0.7333
# Epoch 85/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5441 - accuracy: 0.7339
# Epoch 86/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5439 - accuracy: 0.7332
# Epoch 87/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5438 - accuracy: 0.7335
# Epoch 88/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5444 - accuracy: 0.7331
# Epoch 89/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5441 - accuracy: 0.7330
# Epoch 90/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5441 - accuracy: 0.7337
# Epoch 91/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5440 - accuracy: 0.7324
# Epoch 92/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5439 - accuracy: 0.7338
# Epoch 93/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5441 - accuracy: 0.7331
# Epoch 94/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5441 - accuracy: 0.7331
# Epoch 95/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5437 - accuracy: 0.7338
# Epoch 96/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5439 - accuracy: 0.7343
# Epoch 97/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5439 - accuracy: 0.7338
# Epoch 98/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5436 - accuracy: 0.7328
# Epoch 99/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5439 - accuracy: 0.7336
# Epoch 100/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5436 - accuracy: 0.7340

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 1s - loss: 0.5535 - accuracy: 0.7283 - 1s/epoch - 5ms/step
# Loss: 0.5535353422164917, Accuracy: 0.7282798886299133

# %%
# plotting the accuracy
import matplotlib.pyplot as plt
history_df = pd.DataFrame(fit_model.history, index = range(1, len(fit_model.history['loss'])+1))
history_df.plot(y = 'accuracy')
plt.savefig("Models/model_v1_graph")

# %%
# Export our model to HDF5 file
nn.save('Models/AlphabetSoupCharity_v1.h5')
